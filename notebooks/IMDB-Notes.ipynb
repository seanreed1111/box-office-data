# %% [markdown]
# Movies have form www.imdb.com/title/tt2406566/ #atomic blonde
#
# To get full credits cast, writers, etc:
#
# look for <div id="fullcredits_content" class="header">
#
# inside it will have alternating a tags linking back to the actor names and pages
#
# <a href="/name/nm0000234/?ref_=ttfc_fc_cl_t1"
# itemprop='url'> <span class="itemprop" itemprop="name">Charlize Theron</span>
# </a>
# <a href="/name/nm0564215/?ref_=ttfc_fc_cl_t2"
# itemprop='url'> <span class="itemprop" itemprop="name">James McAvoy</span>
# </a>
#
#
# To download full source of website:
# view-source:http://www.imdb.com/title/tt2406566/fullcredits

# %%
import requests
import urllib.parse as parse
from time import sleep

# %%
pwd()
# Out:
# '/Users/seanreed1/AnacondaProjects/scrapy-projects/movie-project/box-office-data/notebooks'

# %%
title_nums = ['tt0085244'] #The Big Chill

# %%
o = parse.urlparse("http://www.imdb.com/title/tt0085244")
o
# Out:
# ParseResult(scheme='http', netloc='www.imdb.com', path='/title/tt0085244', params='', query='', fragment='')

# %%
def make_urls():
    base_url = "http://www.imdb.com/title/"
    urls = []
    
    for title in title_nums:
        urls.append(base_url + title + '/')
    return urls

def start():
    s = requests.Session()
    urls = make_urls()
    print('making {} get request(s)'.format({len(urls)}))
    for url in urls:
        try:
            r = s.get(url, timeout=10, hooks=dict(response=write))
            print("request headers {}".format({r.requests.headers}))
            print("response headers {}".format({r.headers}))
        except Exception as e:
            print("accessing url.. {}".format({url}))
            print("request headers {}".format({r.requests.headers}))
            print("response headers {}".format({r.headers}))         
            print('Exception encountered at position 1:', e)
            
    return urls



def write(response, **kwargs):

    print('writing file from..{} '.format({response.url}))  
    filename =  response.url + ".html"
    with open(filename, 'wb') as f:
        f.write(response.content)
        f.write(response.url.encode('utf-8'))
        print('saved file %s' % filename)

def my_count():
    n = 1000
    while True:
        yield n
        n += 1
    
numbers = my_count()
try:
    urls = start()
except ReadTimeoutError:
    print('ReadTimeoutError encountered!')
except Exception as err:
    print('Exception encountered at position 2:', err)
# Out:
# making {1} get request(s)
# writing file from..{'http://www.imdb.com/title/tt0085244/'}
# accessing url.. {'http://www.imdb.com/title/tt0085244/'}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1745ff0569fa> in start()
#      13         try:
# ---> 14             r = requests.get(url, timeout=10, hooks=dict(response=write))
#      15             print("request headers {}".format({r.requests.headers}))
#
# /anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#
# /anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#
# /anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#
# /anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Response manipulation hooks
# --> 646         r = dispatch_hook('response', hooks, r, **kwargs)
#     647
#
# /anaconda/lib/python3.6/site-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      30         for hook in hooks:
# ---> 31             _hook_data = hook(hook_data, **kwargs)
#      32             if _hook_data is not None:
#
# <ipython-input-7-1745ff0569fa> in write(response, **kwargs)
#      30     filename =  response.url + ".html"
# ---> 31     with open(filename, 'wb') as f:
#      32         f.write(response.content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'http://www.imdb.com/title/tt0085244/.html'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-1745ff0569fa> in <module>()
#      43 try:
# ---> 44     urls = start()
#      45 except ReadTimeoutError:
#
# <ipython-input-7-1745ff0569fa> in start()
#      18             print("accessing url.. {}".format({url}))
# ---> 19             print("request headers {}".format({r.requests.headers}))
#      20             print("response headers {}".format({r.headers}))
#
# UnboundLocalError: local variable 'r' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1745ff0569fa> in <module>()
#      43 try:
#      44     urls = start()
# ---> 45 except ReadTimeoutError:
#      46     print('ReadTimeoutError encountered!')
#      47 except Exception as err:
#
# NameError: name 'ReadTimeoutError' is not defined

# %%
from requests import Request, Session

s = Session()

# %%
url = "http://www.imdb.com/title/tt0085244"

# %%
r = s.get('http://en.wikipedia.org/wiki/Monty_Python')

# %%
r.request.headers
# Out:
# {'User-Agent': 'python-requests/2.14.2', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
r.headers
# Out:
# {'Date': 'Tue, 01 Aug 2017 23:36:36 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '73227', 'Connection': 'keep-alive', 'Server': 'mw1257.eqiad.wmnet', 'X-Powered-By': 'HHVM/3.18.2', 'Content-Encoding': 'gzip', 'P3P': 'CP="This is not a P3P policy! See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'X-Content-Type-Options': 'nosniff', 'Content-language': 'en', 'X-UA-Compatible': 'IE=Edge', 'Vary': 'Accept-Encoding,Cookie,Authorization', 'Link': '</static/images/project-logos/enwiki.png>;rel=preload;as=image;media=not all and (min-resolution: 1.5dppx),</static/images/project-logos/enwiki-1.5x.png>;rel=preload;as=image;media=(min-resolution: 1.5dppx) and (max-resolution: 1.999999dppx),</static/images/project-logos/enwiki-2x.png>;rel=preload;as=image;media=(min-resolution: 2dppx)', 'Last-Modified': 'Tue, 01 Aug 2017 14:41:32 GMT', 'Backend-Timing': 'D=1143279 t=1501598535994072', 'X-Varnish': '791514503 784575866, 865633008 529333129', 'Via': '1.1 varnish-v4, 1.1 varnish-v4', 'Age': '32058', 'X-Cache': 'cp1068 hit/4, cp1055 hit/36', 'X-Cache-Status': 'hit', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Set-Cookie': 'WMF-Last-Access=01-Aug-2017;Path=/;HttpOnly;secure;Expires=Sat, 02 Sep 2017 12:00:00 GMT, WMF-Last-Access-Global=01-Aug-2017;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Sat, 02 Sep 2017 12:00:00 GMT, GeoIP=US:NY:New_York:40.75:-74.00:v4; Path=/; secure; Domain=.wikipedia.org', 'X-Analytics': 'ns=0;page_id=18942;https=1;nocookies=1', 'X-Client-IP': '173.68.67.114', 'Cache-Control': 'private, s-maxage=0, max-age=0, must-revalidate', 'Accept-Ranges': 'bytes'}

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Monty Python - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Monty_Python","wgTitle":"Monty Python","wgCurRevisionId":791176026,"wgRevisionId":791176026,"wgArticleId":18942,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","CS1 maint: Unfit url","Pages using web citations with no URL","Pages with URL errors","EngvarB from June 2017","Use dmy dates from July 2017","Pages using Infobox comedian with unknown parameters","Official website different in Wikidata and Wikipedia","Articles with DMOZ links","Wikipedia articles with VIAF identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with ISNI identifiers","Wikipedia articles with GND identifiers","Wikipedia articles with SELIBR identifiers","Wikipedia articles with BNF identifiers","Wikipedia articles with MusicBrainz identifiers","Wikipedia articles with NLA identifiers","Monty Python","British comedy troupes","British television comedy","Surreal comedy","Virgin Records artists","Arista Records artists","European Film Awards winners (people)","Charisma Records artists","1969 establishments in England","1983 disestablishments in England","Empire Inspiration Award winners"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Monty_Python","wgRelevantArticleId":18942,"wgRequestId":"WYCTRwpAMFwAAI3uC7oAAABB","wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":false,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":false,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikibaseItemId":"Q16402","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["preload","preloadparams","preloadtitle","undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.math.styles":"ready","ext.cite.styles":"ready","ext.timeline.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"read ...

# %%
imdb = s.get(url)
print(imdb.request.headers)
print(imdb.headers)
# Out:
# {'User-Agent': 'python-requests/2.14.2', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# {'Date': 'Tue, 01 Aug 2017 23:38:05 GMT', 'Server': 'Server', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Security-Policy': "frame-ancestors 'self' imdb.com *.imdb.com *.media-imdb.com withoutabox.com *.withoutabox.com amazon.com *.amazon.com amazon.co.uk *.amazon.co.uk amazon.de *.amazon.de translate.google.com images.google.com www.google.com www.google.co.uk search.aol.com bing.com www.bing.com", 'Content-Type': 'text/html;charset=UTF-8', 'Content-Language': 'en-US', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding,User-Agent', 'Set-Cookie': 'uu=BCYvx5p2vtBeSLT5Haf7Scoef_Yw31SRXEhvEmkLxraLL_LqS-yu_P4-_qVfEx4UpAgkcRmWgioX%0D%0AC5OyMLe4d5284Z0S-7qeuXl3tAB1MvCoYnm9GsfvYblPP5mk41AQIwBQOoUK17ILxfExtTXiYjCU%0D%0AVGU0iSrDLAiN_k4E8bhY3ADnD1jOUHRawjbPWPOFZXCCwKpGXOgNN43jxAi67tsqywSvvUIp0Cvu%0D%0AYidAZL_LrFDdkfL_rUks82MGuAqvovm4T6mGDKIB147dbGNCFdC_L1YefrJ6ed7lWUM-uD3FlRY%0D%0A; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 02:52:13 GMT; Path=/, session-id=000-0000000-0000000; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 02:52:13 GMT; Path=/, session-id-time=2132350685; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 02:52:13 GMT; Path=/', 'P3P': 'policyref="http://i.imdb.com/images/p3p.xml",CP="CAO DSP LAW CUR ADM IVAo IVDo CONo OTPo OUR DELi PUBi OTRi BUS PHY ONL UNI PUR FIN COM NAV INT DEM CNT STA HEA PRE LOC GOV OTC "', 'Transfer-Encoding': 'chunked'}

# %%
imdb.text
# Out:
# '\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt0085244?src=mdot">\n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "0CZNRH990MDEKY7Y18JH";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Ftitle%2Ftt0085244%2F";\n            </script>\n \n\n        \n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>The Big Chill (1983) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n        \n            <link rel="canonical" href="http://www.imdb.com/title/tt0085244/" />\n            <meta property="og:url" content="http://www.imdb.com/title/tt0085244/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB522736552_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB522736556_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/x-icon" href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB522736561_.ico" />\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/image ...

# %%
from requests import Request, Session

# %%
title_nums = ["tt0295700"] #Wrong Turn

# %%
def make_urls():
    base_url = "http://www.imdb.com/title/"
    urls = []
    
    for title in title_nums:
        urls.append(base_url + title + '/')
    return urls

# %%
def my_count():
    n = 1000
    while True:
        yield n
        n += 1
    
numbers = my_count()

# %%
def start(my_session = None):
    
    urls = make_urls()
    print('Urls', urls)
    
    for url in urls:
        try:
            r = my_session.get(url)
            print("request headers",r.request.headers)
            print("response headers",r.headers)
        except Exception as e:
            print("accessing url", url)    
            print('Exception encountered at position 1:', e)
            
    return r, urls

# %%
def write_result(response, *args, **kwargs):

    print('writing file from..{} '.format({response.url}))  
    filename =  "test1.html"
    with open(filename, 'wb') as f:
        f.write(response.content)
        f.write(response.url.encode('utf-8'))
        print('saved file %s' % filename)

# %%
'''from requests import Request, Session

s = Session()
req = Request('GET',  url, data=data, headers=headers)

prepped = s.prepare_request(req)
# do something with prepped.body
prepped.body = 'Seriously, send exactly these bytes.'

# do something with prepped.headers
prepped.headers['Keep-Dead'] = 'parrot'

resp = s.send(prepped,
    stream=stream,
    verify=verify,
    proxies=proxies,
    cert=cert,
    timeout=timeout
)

print(resp.status_code)'''

# write new start function below

def start(my_session = None):
    
    urls = make_urls()
    print('Urls', urls)
    
    for url in urls:
        try:
            my_req = Request('GET', url, hooks=dict(response=write_result))
            prepped = my_session.prepare_request(my_req)
            print("accessing url", url)   
            r = my_session.send(prepped, timeout=10)
            print("request headers",r.request.headers)
            print("response headers",r.headers)
        except Exception as e:
            print("accessing url", url)    
            print('Exception encountered at position 1:', e)
            
    return r, urls

# %%
with Session() as s:
    try:
        start_tuple3 = start(s)
    except Exception as err:
        print('Exception encountered at position 2:', err)
# Out:
# Urls ['http://www.imdb.com/title/tt0295700/']
# accessing url http://www.imdb.com/title/tt0295700/
# writing file from..{'http://www.imdb.com/title/tt0295700/'}
# saved file test1.html
# request headers {'User-Agent': 'python-requests/2.14.2', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# response headers {'Date': 'Wed, 02 Aug 2017 03:55:45 GMT', 'Server': 'Server', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Security-Policy': "frame-ancestors 'self' imdb.com *.imdb.com *.media-imdb.com withoutabox.com *.withoutabox.com amazon.com *.amazon.com amazon.co.uk *.amazon.co.uk amazon.de *.amazon.de translate.google.com images.google.com www.google.com www.google.co.uk search.aol.com bing.com www.bing.com", 'Content-Type': 'text/html;charset=UTF-8', 'Content-Language': 'en-US', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding,User-Agent', 'Set-Cookie': 'uu=BCYujh2160ujC8DkjxLzlmE22AghskW4wrXp2HeX99NnmZyvoErvrE-C46I5yRX0fAgz5o2VGBu1%0D%0A2V6XTZM3DRtduNFGwRWlGSfu5WUNS75lvc1b9Qq9ul6JqQfNlj6t4X5vOU8NWoBTeryo1gWIiHnp%0D%0Afd4Z3r46iaOitfX8ED4KrJ4KGnza4UIeZqp3XfI270w9PVw5JxJCTKoB6G8fRasewGEOxbaLm0US%0D%0AWpjYDXbSRaWyyEgH6SNWXQEVWlPrg5VpMZdaZ_0NFhQ46wlj0f-jDA%0D%0A; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 07:09:53 GMT; Path=/, session-id=000-0000000-0000000; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 07:09:53 GMT; Path=/, session-id-time=2132366146; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 07:09:53 GMT; Path=/', 'P3P': 'policyref="http://i.imdb.com/images/p3p.xml",CP="CAO DSP LAW CUR ADM IVAo IVDo CONo OTPo OUR DELi PUBi OTRi BUS PHY ONL UNI PUR FIN COM NAV INT DEM CNT STA HEA PRE LOC GOV OTC "', 'Transfer-Encoding': 'chunked'}

# %%
# !head test1.html
# Out:
# <!DOCTYPE html>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-b6fd0ee96e4a> in <module>()
# ----> 1 hooks=dict(response=write_response)
#
# NameError: name 'write_response' is not defined

# %%
# !ls
# Out:
# 1000.html                             The-Numbers-Data-Exploration.ipynb
# 1001.html                             The-Numbers-HTML-Parser.ipynb
# IMDB-Notes.ipynb                      The-Numbers-Parser-v2.ipynb
# OMDB-Data-Download.ipynb              backup
# The-Numbers-Box-Office-Download.ipynb

# %%
start_tuple[0].text
# Out:
# '\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt0324216?src=mdot">\n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "1F07ERRN2MQR1SS6BQJ3";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Ftitle%2Ftt0324216%2F";\n            </script>\n \n\n        \n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>The Texas Chainsaw Massacre (2003) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n        \n            <link rel="canonical" href="http://www.imdb.com/title/tt0324216/" />\n            <meta property="og:url" content="http://www.imdb.com/title/tt0324216/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB522736552_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB522736556_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/x-icon" href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB522736561_.ico" />\n        <link href="http://ia.media-imdb.com/images/G ...

# %%
start_tuple2[0].text
# Out:
# '\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt0420294?src=mdot">\n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "067RV83HK9NXBYTHPGQ7";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Ftitle%2Ftt0420294%2F";\n            </script>\n \n\n        \n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>The Texas Chainsaw Massacre: The Beginning (2006) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n        \n            <link rel="canonical" href="http://www.imdb.com/title/tt0420294/" />\n            <meta property="og:url" content="http://www.imdb.com/title/tt0420294/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB522736552_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB522736556_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/x-icon" href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB522736561_.ico" />\n        <link href="http://ia.media-im ...

# %%
print(start_tuple[0].request.headers)
print(start_tuple[0].headers)
# Out:
# {'User-Agent': 'python-requests/2.14.2', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# {'Content-Language': 'en-US', 'Content-Security-Policy': "frame-ancestors 'self' imdb.com *.imdb.com *.media-imdb.com withoutabox.com *.withoutabox.com amazon.com *.amazon.com amazon.co.uk *.amazon.co.uk amazon.de *.amazon.de translate.google.com images.google.com www.google.com www.google.co.uk search.aol.com bing.com www.bing.com", 'Content-Type': 'text/html;charset=UTF-8', 'Date': 'Wed, 02 Aug 2017 00:18:05 GMT', 'P3p': 'policyref="http://i.imdb.com/images/p3p.xml",CP="CAO DSP LAW CUR ADM IVAo IVDo CONo OTPo OUR DELi PUBi OTRi BUS PHY ONL UNI PUR FIN COM NAV INT DEM CNT STA HEA PRE LOC GOV OTC "', 'Server': 'Server', 'Set-Cookie': 'uu=BCYmrfdH8d0ZLvco3OO-xJMUOCaLMXwjidD02TMJoyD647v0pmMnIxmW5R_ydgyicqFRZBR34S2B%0D%0A68DyZHlifJrZV7zHBrIGuKgJ-SU0EViMrpGzmneMdEt0sFf1vkY2yYE8Nq-FD_NncVLfMa8lIBR4%0D%0AV8yLdbGR77qkqhURxi2pudn32Yv0bpEV2Ky8WyD0y9c1hOZIPMNcWMzVIhRVM3sN86Eu3cjOs3An%0D%0AfX9xoq-uoeh500sMYz-6TupjaTAQ4MheBpvS9qrbcGr0i4y5cCtjDiq47qaNoMIwJTBHK0pjsgo%0D%0A; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 03:32:13 GMT; Path=/, session-id=000-0000000-0000000; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 03:32:13 GMT; Path=/, session-id-time=2132353085; Domain=.imdb.com; Expires=Mon, 20-Aug-2085 03:32:13 GMT; Path=/', 'Vary': 'Accept-Encoding,User-Agent', 'X-Frame-Options': 'SAMEORIGIN', 'Transfer-Encoding': 'chunked'}

# %%
start_tuple[0].text
# Out:
# '\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt0324216?src=mdot">\n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "0K4E874XDJV5BST3YRBE";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Ftitle%2Ftt0324216%2F";\n            </script>\n \n\n        \n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>The Texas Chainsaw Massacre (2003) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n        \n            <link rel="canonical" href="http://www.imdb.com/title/tt0324216/" />\n            <meta property="og:url" content="http://www.imdb.com/title/tt0324216/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB522736552_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB522736556_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/x-icon" href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB522736561_.ico" />\n        <link href="http://ia.media-imdb.com/images/G ...

# %%
'''from requests import Request, Session

s = Session()
req = Request('GET',  url, data=data, headers=headers)

prepped = s.prepare_request(req)

# do something with prepped.body
prepped.body = 'Seriously, send exactly these bytes.'

# do something with prepped.headers
prepped.headers['Keep-Dead'] = 'parrot'

resp = s.send(prepped,
    stream=stream,
    verify=verify,
    proxies=proxies,
    cert=cert,
    timeout=timeout
)

print(resp.status_code)
'''

# %%
{"response","write"}
# Out:
# {'response', 'write'}

# %%
'''
import requests


def print_url(r, *args, **kwargs):
    print(r.url)


hooks = dict(response=print_url)
r = requests.get('http://httpbin.org', hooks=dict(response=print_url))
print(r.status_code)'''
